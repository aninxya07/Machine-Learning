# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # **1. Distribution plot for numeric columns:**

# %%
sns.displot(df['RestingBP'], kde = True, color = 'Blue')

# %%
sns.distplot(df['RestingBP'], color = 'Blue')
# Out:
# <ipython-input-10-854ebfd77950>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], color = 'Blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.displot(df['Cholesterol'], kde = True, color = 'Blue')

# %%
sns.distplot(df['Cholesterol'], color = 'Blue')
# Out:
# <ipython-input-12-c7654a7813c7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'], color = 'Blue')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.displot(df['MaxHR'], kde = True, color = 'Blue')

# %%
sns.displot(df['Oldpeak'], kde = True, color = 'Blue')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # **2. Pie Charts for Categorical Columns:**

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby('Sex').size().plot(kind = 'pie', title = 'sex', autopct = '%.2f%%', figsize = (7,7))
# Out:
# <Axes: title={'center': 'sex'}>

# %%
df.groupby('ChestPainType').size()
# Out:
# ChestPainType
# ASY    496
# ATA    173
# NAP    203
# TA      46
# dtype: int64

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', title = 'Chest Pain Type', autopct = '%.2f%%', figsize = (7,7))
# Out:
# <Axes: title={'center': 'Chest Pain Type'}>

# %%
df.groupby('RestingECG').size()
# Out:
# RestingECG
# LVH       188
# Normal    552
# ST        178
# dtype: int64

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', title = 'Resting ECG', autopct = '%.2f%%', figsize = (7,7))
# Out:
# <Axes: title={'center': 'Resting ECG'}>

# %%
df.groupby('ST_Slope').size()
# Out:
# ST_Slope
# Down     63
# Flat    460
# Up      395
# dtype: int64

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', title = 'ST Slope', autopct = '%.2f%%', figsize = (7,7))
# Out:
# <Axes: title={'center': 'ST Slope'}>

# %%
df.groupby('HeartDisease').size()
# Out:
# HeartDisease
# 0    410
# 1    508
# dtype: int64

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', title = 'Heart Disease', autopct = '%.2f%%', figsize = (7,7))
# Out:
# <Axes: title={'center': 'Heart Disease'}>
