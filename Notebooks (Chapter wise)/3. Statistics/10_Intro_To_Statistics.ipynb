# %% [markdown]
# # **Importing numpy ans pandas**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **reading the students marks file using pandas**

# %%
df = pd.read_csv('Students_marks.csv')
df
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %%
df.describe()
# Out:
#        Roll No.  Data Structure  Mathematics  Operating System  Average marks
# count  10.00000       10.000000     10.00000         10.000000      10.000000
# mean    5.50000       40.700000     23.10000         20.600000      28.131000
# std     3.02765       52.493492      3.60401          6.619836      19.337093
# min     1.00000       21.000000     18.00000          9.000000      18.000000
# 25%     3.25000       23.000000     21.25000         15.500000      20.330000
# 50%     5.50000       24.000000     22.50000         21.500000      22.665000
# 75%     7.75000       25.750000     24.75000         26.500000      24.997500
# max    10.00000      190.000000     30.00000         28.000000      82.660000

# %% [markdown]
# # **1. Data Preprocessing**

# %% [markdown]
# # **the mean value of data struture is 40.7 but the full marks of data structures was 30, means there's some error which we need to fix**

# %%
df
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %% [markdown]
# # **Vashuda scored 190 in ds which is impossible bcz the F.M. was 30, so we're removing this row**

# %%
df.drop(index = 5, axis = 1, inplace = True)
df
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# 3          25.33  Very Good
# 4          18.00       Okay
# 6          23.33       Good
# ...

# %% [markdown]
# # **again checking describe**

# %%
df.describe()   # now the mean value is correct
# Out:
#         Roll No.  Data Structure  Mathematics  Operating System  Average marks
# count   9.000000        9.000000     9.000000          9.000000       9.000000
# mean    5.444444       24.111111    22.333333         19.777778      22.072222
# std     3.205897        2.027588     2.828427          6.457124       2.773030
# min     1.000000       21.000000    18.000000          9.000000      18.000000
# 25%     3.000000       23.000000    21.000000         15.000000      20.330000
# 50%     5.000000       24.000000    22.000000         21.000000      22.000000
# 75%     8.000000       25.000000    24.000000         25.000000      24.000000
# max    10.000000       28.000000    27.000000         28.000000      26.000000

# %% [markdown]
# # **2. Conclude Various Inferences**

# %% [markdown]
# # **seeing the mean value of OS, we can say that the value is less (19). So students need to work hard in OS in order to improve in this subject**

# %% [markdown]
# # **3. Statistical Visualization**

# %% [markdown]
# # **Importing Matplot library for graph representation**

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(df['Name'], df['Operating System'])
plt.title('Students Marks in Operating System')
plt.xlabel('Students Name')
plt.ylabel('Students Marks')
plt.show()

# %%
plt.plot(df['Name'], df['Data Structure'])
plt.title('Students Marks in Data Structure')
plt.xlabel('Students Name')
plt.ylabel('Students Marks')
plt.show()
